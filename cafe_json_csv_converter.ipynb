# %%
import csv
import json
import pprint

# %%
# for conversationo2.csv
csvpath="C:/Users/soon kien yuan/Documents/GitHub/AI-School-Project/conversationo2.csv"

jsonpath="C:/Users/soon kien yuan/Documents/GitHub/AI-School-Project/cafe.json"


data=[{}]
#format_data={"A":[{data}]}

# %%
#open and read csv
#with open(csvpath) as csvfile:
    #csvreader=csv.DictReader(csvfile)
     # Convert each row into a dictionary
    # and add it to data
    #for rows in csvreader:
    # Assuming a column named 'No' to
    # be the primary key
        #key=rows['tag']
        #data[key]=rows

# %%
#with open(jsonpath,"w") as jsonfile:
#    jsonfile.write(json.dumps(data,indent=10))

# %%
#with open(jsonpath) as f:
#	dat = json.load(f)
#	#intents = dat['intents']
#intents
#dat

# %%
# csvfile = open(csvpath, 'r')
# jsonfile = open(jsonpath, 'w')

# fieldnames = ("Question","answer")
# reader = csv.DictReader( csvfile, fieldnames)
# out = json.dumps( [ row for row in reader ] )
# jsonfile.write(out)

# %%
# csvfile = open(csvpath, 'r')
# jsonfile = open(jsonpath, 'w')

# fieldnames = ("Question","answer")
# reader = csv.DictReader( csvfile, fieldnames)
# for row in reader:
#     json.dump(row, jsonfile)
#     jsonfile.write('\n')

# %%
# for the version 1 without tag
csvfile = open(csvpath, 'r')
jsonfile = open(jsonpath, 'w')

fieldnames = ("patterns","responses")
reader = csv.DictReader( csvfile, fieldnames)
out = json.dumps( {"A":[ row for row in reader]} )
jsonfile.write(out)
# Out:
# 121955

# %%
with open(jsonpath) as f:
	dat = json.load(f)
	#intents = dat['intents']
#intents
dat
# Out:
# {'A': [{'patterns': 'hey', 'responses': 'Hello! How may I help you.'},
#   {'patterns': 'do u have coffee',
#    'responses': 'Yes sir  Simple Coffee ,Cappuchino, Americano, Au Laite ,Au Laite Cappucchino ,Chans Espresso ,Con Panna, Black Coffee, Espresso, Frappe ,French Coffee ,Iced Coffee Late ,Irish Coffee, Latte Macchiato and  Wainans Choco Coffee.What would u like to have?'},
#   {'patterns': 'i will take one espresso and 5 americano',
#    'responses': 'Sir thanks for your order. You have ordered 1 espresso and 5 americano.Please wait for sometime.'},
#   {'patterns': 'anything special',
#    'responses': 'We have coffe,pastries,puff pastries and milkshakes.What would you like to have?'},
#   {'patterns': ' suggest something',
#    'responses': 'We have coffe,pastries,puff pastries and milkshakes.What would you like to have?'},
# ...

# %%
# for conversationo3.csv
csvpath="C:/Users/soon kien yuan/Documents/GitHub/AI-School-Project/conversationo3.csv"

jsonpath="C:/Users/soon kien yuan/Documents/GitHub/AI-School-Project/cafe_v2.json"

# %%
#version 2 with tag, where tag = pattern
csvfile = open(csvpath, 'r')
jsonfile = open(jsonpath, 'w')

fieldnames = ("tag","patterns","responses")
reader = csv.DictReader( csvfile, fieldnames)
out = json.dumps( {"A":[ row for row in reader]} )
jsonfile.write(out)
# Out:
# 162641

# %%
with open(jsonpath) as f:
	dat = json.load(f)
	#intents = dat['intents']
#intents
dat
# Out:
# {'A': [{'tag': 'hey',
#    'patterns': 'hey',
#    'responses': 'Hello! How may I help you.'},
#   {'tag': 'do u have coffee',
#    'patterns': 'do u have coffee',
#    'responses': 'Yes sir  Simple Coffee ,Cappuchino, Americano, Au Laite ,Au Laite Cappucchino ,Chans Espresso ,Con Panna, Black Coffee, Espresso, Frappe ,French Coffee ,Iced Coffee Late ,Irish Coffee, Latte Macchiato and  Wainans Choco Coffee.What would u like to have?'},
#   {'tag': 'i will take one espresso and 5 americano',
#    'patterns': 'i will take one espresso and 5 americano',
#    'responses': 'Sir thanks for your order. You have ordered 1 espresso and 5 americano.Please wait for sometime.'},
#   {'tag': 'anything special',
#    'patterns': 'anything special',
#    'responses': 'We have coffe,pastries,puff pastries and milkshakes.What would you like to have?'},
#   {'tag': ' suggest something',
#    'patterns': ' suggest something',
# ...

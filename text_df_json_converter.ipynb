# %%
import pandas as pd
import json
import csv

# %%
text_path="C:/Users/soon kien yuan/Desktop/ump/sem 4/Artificial Intelligence/project/dialogs.txt"

text_link="""https://storage.googleapis.com/kagglesdsdata/datasets/715041/1245709/dialogs.txt?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20220610%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20220610T195730Z&X-Goog-Expires=259199&X-Goog-SignedHeaders=host&X-Goog-Signature=..."""

columns=["patterns","responses"]

# %%
df = pd.read_csv(text_link,sep='\t',
                 names=columns)
df_reset=df.set_index('patterns')
df_reset
# Out:
#                                                                                             responses
# patterns
# hi, how are you doing?                                                  i'm fine. how about yourself?
# i'm fine. how about yourself?                                     i'm pretty good. thanks for asking.
# i'm pretty good. thanks for asking.                                 no problem. so how have you been?
# no problem. so how have you been?                                    i've been great. what about you?
# i've been great. what about you?                             i've been good. i'm in school right now.
# ...                                                                                               ...
# that's a good question. maybe it's not old age.                                 are you right-handed?
# are you right-handed?                                                               yes. all my life.
# yes. all my life.                                   you're wearing out your right hand. stop using...
# you're wearing out your right hand. stop using ...        but i do all my writing with my right hand.
# but i do all my writing with my right hand.         start typing instead. that way your left hand ...
#
# [3725 rows x 1 columns]

# %%
result = df_reset.to_json(orient="table")
parsed = json.loads(result)
json.dumps(parsed, indent=4)
# Out:
# '{\n    "schema": {\n        "fields": [\n            {\n                "name": "patterns",\n                "type": "string"\n            },\n            {\n                "name": "responses",\n                "type": "string"\n            }\n        ],\n        "pandas_version": "0.20.0"\n    },\n    "data": [\n        {\n            "patterns": "hi, how are you doing?",\n            "responses": "i\'m fine. how about yourself?"\n        },\n        {\n            "patterns": "i\'m fine. how about yourself?",\n            "responses": "i\'m pretty good. thanks for asking."\n        },\n        {\n            "patterns": "i\'m pretty good. thanks for asking.",\n            "responses": "no problem. so how have you been?"\n        },\n        {\n            "patterns": "no problem. so how have you been?",\n            "responses": "i\'ve been great. what about you?"\n        },\n        {\n            "patterns": "i\'ve been great. what about you?",\n            "responses": "i\'ve been good. i\'m in school right now."\n        },\n        {\n            "patterns": "i\'ve been good. i\'m in school right now.",\n            "responses": "what school do you go to?"\n        },\n        {\n            "patterns": "what school do you go to?",\n            "responses": "i go to pcc."\n        },\n        {\n            "patterns": "i go to pcc.",\n            "responses": "do you like it there?"\n        },\n        {\n            "patterns": "do you like it there?",\n            "responses": "it\'s okay. it\'s a really big campus."\n        },\n        {\n            "patterns": "it\'s okay. it\'s a really big campus.",\n            "responses": "good luck with school."\n        },\n        {\n            "patterns": "good luck with school.",\n            "responses": "thank you very much."\n        },\n        {\n            "patterns": "how\'s it going?",\n            "responses": "i\'m doing well. how about you?"\n        },\n        {\n            "patterns": "i\'m doing well. how about you?",\n            "responses": "never better, thanks."\n        },\n        {\n            "patterns": "never better, thanks.",\n            "responses": "so how have you been lately?"\n        },\n        {\n            "patterns": "so how have you been lately?",\n            "responses": "i\'ve actually been pretty good. you?"\n        },\n        {\n            "patterns": "i\'ve actually been pretty good. you?",\n            "responses": "i\'m actually in school right now."\n        },\n        {\n            "patterns": "i\'m actually in school right now.",\n            "responses": "which school do you attend?"\n        },\n        {\n            "patterns": "which school do you attend?",\n            "responses": "i\'m attending pcc right now."\n        },\n        {\n            "patterns": "i\'m attending pcc right now.",\n            "responses": "are you enjoying it there?"\n        },\n        {\n            "patterns": "are you enjoying it there?",\n            "responses": "it\'s not bad. there are a lot of people there."\n        },\n        {\n            "patterns": "it\'s not bad. there are a lot of people there.",\n            "responses": "good luck with that."\n        },\n        {\n            "patterns": "good luck with that.",\n            "responses": "thanks."\n        },\n        {\n            "patterns": "how are you doing today?",\n            "responses": "i\'m doing great. what about you?"\n        },\n        {\n            "patterns": "i\'m doing great. what about you?",\n            "responses": "i\'m absolutely lovely, thank you."\n        },\n        {\n            "patterns": "i\'m absolutely lovely, thank you.",\n            "responses": "everything\'s been good with you?"\n        },\n        {\n            "patterns": "everything\'s been good with you?",\n            "responses": "i haven\'t been better. how about yourself?"\n        },\n        {\n            "patterns": "i haven\'t been better. h ...

# %%
with open('simpleQnA.json', 'w') as f:
    result = df_reset.to_json(orient="table")
    parsed = json.loads(result)
    out=json.dumps(parsed, indent=4) 
    f.write(out)
    #f.write(df.to_json(orient='records'))

# %%
jsonpath='simpleQnA.json'

with open(jsonpath) as f:
	dat = json.load(f)
	#intents = dat['intents']
#intents
dat
# Out:
# {'schema': {'fields': [{'name': 'patterns', 'type': 'string'},
#    {'name': 'responses', 'type': 'string'}],
#   'pandas_version': '0.20.0'},
#  'data': [{'patterns': 'hi, how are you doing?',
#    'responses': "i'm fine. how about yourself?"},
#   {'patterns': "i'm fine. how about yourself?",
#    'responses': "i'm pretty good. thanks for asking."},
#   {'patterns': "i'm pretty good. thanks for asking.",
#    'responses': 'no problem. so how have you been?'},
#   {'patterns': 'no problem. so how have you been?',
#    'responses': "i've been great. what about you?"},
#   {'patterns': "i've been great. what about you?",
#    'responses': "i've been good. i'm in school right now."},
#   {'patterns': "i've been good. i'm in school right now.",
#    'responses': 'what school do you go to?'},
#   {'patterns': 'what school do you go to?', 'responses': 'i go to pcc.'},
#   {'patterns': 'i go to pcc.', 'responses': 'do you like it there?'},
#   {'patterns': 'do you like it there?',
#    'responses': "it's okay. it's a really big campus."},
#   {'patterns': "it's okay. it's a really big campus.",
#    'responses': 'good luck with school.'},
#   {'patterns': 'good luck with school.', 'responses': 'thank you very much.'},
#   {'patterns': "how's it going?",
#    'responses': "i'm doing well. how about you?"},
#   {'patterns': "i'm doing well. how about you?",
#    'responses': 'never better, thanks.'},
#   {'patterns': 'never better, thanks.',
#    'responses': 'so how have you been lately?'},
#   {'patterns': 'so how have you been lately?',
#    'responses': "i've actually been pretty good. you?"},
#   {'patterns': "i've actually been pretty good. you?",
#    'responses': "i'm actually in school right now."},
#   {'patterns': "i'm actually in school right now.",
#    'responses': 'which school do you attend?'},
#   {'patterns': 'which school do you attend?',
#    'responses': "i'm attending pcc right now."},
#   {'patterns': "i'm attending pcc right now.",
#    'responses': 'are you enjoying it there?'},
#   {'patterns': 'are you enjoying it there?',
#    'responses': "it's not bad. there are a lot of people there."},
#   {'patterns': "it's not bad. there are a lot of people there.",
#    'responses': 'good luck with that.'},
#   {'patterns': 'good luck with that.', 'responses': 'thanks.'},
#   {'patterns': 'how are you doing today?',
#    'responses': "i'm doing great. what about you?"},
#   {'patterns': "i'm doing great. what about you?",
#    'responses': "i'm absolutely lovely, thank you."},
#   {'patterns': "i'm absolutely lovely, thank you.",
#    'responses': "everything's been good with you?"},
#   {'patterns': "everything's been good with you?",
#    'responses': "i haven't been better. how about yourself?"},
#   {'patterns': "i haven't been better. how about yourself?",
#    'responses': 'i started school recently.'},
#   {'patterns': 'i started school recently.',
#    'responses': 'where are you going to school?'},
#   {'patterns': 'where are you going to school?',
#    'responses': "i'm going to pcc."},
#   {'patterns': "i'm going to pcc.", 'responses': 'how do you like it so far?'},
#   {'patterns': 'how do you like it so far?',
#    'responses': 'i like it so far. my classes are pretty good right now.'},
#   {'patterns': 'i like it so far. my classes are pretty good right now.',
#    'responses': 'i wish you luck.'},
#   {'patterns': "it's an ugly day today.",
#    'responses': 'i know. i think it may rain.'},
#   {'patterns': 'i know. i think it may rain.',
#    'responses': "it's the middle of summer, it shouldn't rain today."},
#   {'patterns': "it's the middle of summer, it shouldn't rain today.",
#    'responses': 'that would be weird.'},
#   {'patterns': 'that would be weird.',
#    'responses': "yeah, especially since it's ninety degrees outside."},
#   {'patterns': "yeah, especially since it's ninety degrees outside.",
#    'responses': 'i know, it would be horrible if it rained and it was hot outside.'},
#   {'patterns': 'i know, it would be horrible if it rained and it was hot outside.',
#    'responses': 'yes, it would be. '},
#   {'patterns': 'yes, it would be. ',
#    'responses': "i really wish it wasn't so hot every day. "},
#   {'patterns': "i really wish it wasn't so hot every day. ",
#    'responses': "me too. i can't wait until winter."},
#   {'patterns': "me too. i can't wait until winter.",
#    'responses': 'i like winter too, but sometimes it gets too cold.'},
#   {'patterns': 'i like winter too, but sometimes it gets too cold.',
#    'responses': "i'd rather be cold than hot."},
#   {'patterns': "i'd rather be cold than hot.", 'responses': 'me too.'},
#   {'patterns': "it doesn't look very nice outside today.",
#    'responses': "you're right. i think it's going to rain later."},
#   {'patterns': "you're right. i think it's going to rain later.",
#    'responses': "in the middle of the summer, it shouldn't be raining."},
#   {'patterns': "in the middle of the summer, it shouldn't be raining.",
#    'responses': "that wouldn't seem right."},
#   {'patterns': "that wouldn't seem right.",
#    'responses': "considering that it's over ninety degrees outside, that would be weird."},
#   {'patterns': "considering that it's over ninety degrees outside, that would be weird.",
#    'responses': "exactly, it wouldn't be nice if it started raining. it's too hot."},
#   {'patterns': "exactly, it wouldn't be nice if it started raining. it's too hot.",
#    'responses': "i know, you're absolutely right."},
#   {'patterns': "i know, you're absolutely right.",
#    'responses': 'i wish it would cool off one day.'},
#   {'patterns': 'i wish it would cool off one day.',
#    'responses': "that's how i feel, i want winter to come soon."},
#   {'patterns': "that's how i feel, i want winter to come soon.",
#    'responses': 'i enjoy the winter, but it gets really cold sometimes.'},
#   {'patterns': 'i enjoy the winter, but it gets really cold sometimes.',
#    'responses': "i know what you mean, but i'd rather be cold than hot."},
#   {'patterns': "i know what you mean, but i'd rather be cold than hot.",
#    'responses': "that's exactly how i feel."},
#   {'patterns': 'i wish it was a nicer day today.',
#    'responses': "that is true. i hope it doesn't rain."},
#   {'patterns': "that is true. i hope it doesn't rain.",
#    'responses': "it wouldn't rain in the middle of the summer."},
#   {'patterns': "it wouldn't rain in the middle of the summer.",
#    'responses': "it wouldn't seem right if it started raining right now."},
#   {'patterns': "it wouldn't seem right if it started raining right now.",
#    'responses': 'it would be weird if it started raining in ninety degree weather.'},
#   {'patterns': 'it would be weird if it started raining in ninety degree weather.',
#    'responses': 'any rain right now would be pointless.'},
#   {'patterns': 'any rain right now would be pointless.',
#    'responses': "that's right, it really would be."},
#   {'patterns': "that's right, it really would be.",
#    'responses': 'i want it to cool down some.'},
#   {'patterns': 'i want it to cool down some.',
#    'responses': "i know what you mean, i can't wait until it's winter."},
#   {'patterns': "i know what you mean, i can't wait until it's winter.",
#    'responses': "winter is great. i wish it didn't get so cold sometimes though."},
#   {'patterns': "winter is great. i wish it didn't get so cold sometimes though.",
#    'responses': 'i would rather deal with the winter than the summer.'},
#   {'patterns': "it's such a nice day.", 'responses': 'yes, it is.'},
#   {'patterns': 'yes, it is.', 'responses': 'it looks like it may rain soon.'},
#   {'patterns': 'it looks like it may rain soon.',
#    'responses': 'yes, and i hope that it does.'},
#   {'patterns': 'yes, and i hope that it does.', 'responses': 'why is that?'},
#   {'patterns': 'why is that?',
#    'responses': 'i really love how rain clears the air.'},
#   {'patterns': 'i really love how rain clears the air.',
#    'responses': 'me too. it always smells so fresh after it rains.'},
#   {'patterns': 'me too. it always smells so fresh after it rains.',
#    'responses': 'yes, but i love the night air after it rains.'},
#   {'patterns': 'yes, but i love the night air after it rains.',
#    'responses': 'really? why is it?'},
#   {'patterns': 'really? why is it?',
#    'responses': 'because you can see the stars perfectly.'},
#   {'patterns': 'because you can see the stars perfectly.',
#    'responses': 'i really hope it rains today.'},
#   {'patterns': 'i really hope it rains today.', 'responses': 'yeah, me too.'},
#   {'patterns': "isn't it a nice day?", 'responses': 'it really is.'},
#   {'patterns': 'it really is.',
#    'responses': 'it seems that it may rain today.'},
#   {'patterns': 'it seems that it may rain today.',
#    'responses': 'hopefully it will.'},
#   {'patterns': 'hopefully it will.', 'responses': 'how come?'},
#   {'patterns': 'how come?',
#    'responses': 'i like how clear the sky gets after it rains.'},
#   {'patterns': 'i like how clear the sky gets after it rains.',
#    'responses': 'i feel the same way. it smells so good after it rains.'},
#   {'patterns': 'i feel the same way. it smells so good after it rains.',
#    'responses': 'i especially love the night air when it rains.'},
#   {'patterns': 'i especially love the night air when it rains.',
#    'responses': 'really? why?'},
#   {'patterns': 'really? why?',
#    'responses': 'the stars look so much closer after it rains.'},
#   {'patterns': 'the stars look so much closer after it rains.',
#    'responses': 'i really want it to rain today.'},
#   {'patterns': 'i really want it to rain today.',
#    'responses': 'yeah, so do i.'},
#   {'patterns': "don't you think it's nice out?",
#    'responses': 'yes, i think so too.'},
#   {'patterns': 'yes, i think so too.',
#    'responses': "i think that it's going to rain."},
#   {'patterns': "i think that it's going to rain.",
#    'responses': 'i hope that it does rain.'},
#   {'patterns': 'i hope that it does rain.', 'responses': 'you like the rain?'},
#   {'patterns': 'you like the rain?',
#    'responses': 'the sky looks so clean after it rains. i love it.'},
#   {'patterns': 'the sky looks so clean after it rains. i love it.',
#    'responses': 'i understand. rain does make it smell cleaner.'},
#   {'patterns': 'i understand. rain does make it smell cleaner.',
#    'responses': 'i love most how it is at night after it rains.'},
#   {'patterns': 'i love most how it is at night after it rains.',
#    'responses': 'how come?'},
#   {'patterns': 'how come?',
#    'responses': 'you can see the stars so much more clearly after it rains.'},
#   {'patterns': 'you can see the stars so much more clearly after it rains.',
#    'responses': 'i would love for it to rain today.'},
#   {'patterns': 'i really want to go to the beach this weekend.',
#    'responses': "that sounds like fun. what's the weather going to be like?"},
#   {'patterns': "that sounds like fun. what's the weather going to be like?",
#    'responses': "i heard that it's going to be warm this weekend."},
#   {'patterns': "i heard that it's going to be warm this weekend.",
#    'responses': 'is it going to be perfect beach weather?'},
#   {'patterns': 'is it going to be perfect beach weather?',
#    'responses': 'i believe so.'},
#   {'patterns': 'i believe so.',
#    'responses': "good. i hope it doesn't cool off this weekend."},
#   {'patterns': "good. i hope it doesn't cool off this weekend.",
#    'responses': 'i know. i really want to go to the beach.'},
#   {'patterns': 'i know. i really want to go to the beach.',
#    'responses': 'but you know that california weather is really unpredictable.'},
#   {'patterns': 'but you know that california weather is really unpredictable.',
#    'responses': "you're right. one minute it's hot, and then the next minute it's cold."},
#   {'patterns': "you're right. one minute it's hot, and then the next minute it's cold.",
#    'responses': 'i really wish the weather would just stay the same.'},
#   {'patterns': 'i really wish the weather would just stay the same.',
#    'responses': 'i do too. that way we can have our activities planned ahead of time.'},
#   {'patterns': 'i do too. that way we can have our activities planned ahead of time.',
#    'responses': 'yeah, that would make things a lot easier.'},
#   {'patterns': 'i would like to take a trip to the beach this weekend.',
#    'responses': 'a trip to the beach would be fun. how is the weather going to be?'},
#   {'patterns': 'a trip to the beach would be fun. how is the weather going to be?',
#    'responses': 'the forecast says that it will be warm on the weekend.'},
#   {'patterns': 'the forecast says that it will be warm on the weekend.',
#    'responses': "so do you think it'll be perfect weather for the beach?"},
#   {'patterns': "so do you think it'll be perfect weather for the beach?",
#    'responses': 'it sounds like it will be.'},
#   {'patterns': 'it sounds like it will be.',
#    'responses': "i really hope it doesn't get cold."},
#   {'patterns': "i really hope it doesn't get cold.",
#    'responses': 'that would ruin things, i want to go so badly.'},
#   {'patterns': 'that would ruin things, i want to go so badly.',
#    'responses': 'the weather in california is unpredictable, so you never know.'},
#   {'patterns': 'the weather in california is unpredictable, so you never know.',
#    'responses': 'that is true. the weather is constantly changing.'},
#   {'patterns': 'that is true. the weather is constantly changing.',
#    'responses': 'it would be nice if the weather would never change.'},
#   {'patterns': 'it would be nice if the weather would never change.',
#    'responses': 'that would be great, then we could plan things sooner.'},
#   {'patterns': 'that would be great, then we could plan things sooner.',
#    'responses': 'true. predictable weather would make life easier.'},
#   {'patterns': 'it would be nice to go to the beach sometime this weekend.',
#    'responses': "what's the weather going to be like? i may want to go too."},
#   {'patterns': "what's the weather going to be like? i may want to go too.",
#    'responses': 'the weather this weekend is supposed to be warm.'},
#   {'patterns': 'the weather this weekend is supposed to be warm.',
#    'responses': 'will it be good beach weather?'},
#   {'patterns': 'will it be good beach weather?',
#    'responses': 'i think it will be.'},
#   {'patterns': 'i think it will be.',
#    'responses': "it wouldn't be good if it got cold this weekend."},
#   {'patterns': "it wouldn't be good if it got cold this weekend.",
#    'responses': 'i want this trip to be perfect, i hope it stays warm.'},
#   {'patterns': 'i want this trip to be perfect, i hope it stays warm.',
#    'responses': "this california weather is so uncertain, it's impossible to know what'll happen."},
#   {'patterns': "this california weather is so uncertain, it's impossible to know what'll happen.",
#    'responses': 'i know. every day the weather seems different.'},
#   {'patterns': 'i know. every day the weather seems different.',
#    'responses': "i would love it if it wasn't always so unpredictable."},
#   {'patterns': "i would love it if it wasn't always so unpredictable.",
#    'responses': 'that would make it easier for us to make plans.'},
#   {'patterns': 'hello, may i speak to alice please?',
#    'responses': "this is she. how's it going?"},
#   {'patterns': "this is she. how's it going?",
#    'responses': "i've been trying to call you all day."},
#   {'patterns': "i've been trying to call you all day.",
#    'responses': 'sorry about that. i was cleaning up.'},
#   {'patterns': 'sorry about that. i was cleaning up.',
#    'responses': "it's okay."},
#   {'patterns': "it's okay.",
#    'responses': 'so what were you calling me about?'},
#   {'patterns': 'so what were you calling me about?',
#    'responses': 'oh, i just wanted to see if you wanted to hang out tomorrow.'},
#   {'patterns': 'oh, i just wanted to see if you wanted to hang out tomorrow.',
#    'responses': 'sure, what did you want to do?'},
#   {'patterns': 'sure, what did you want to do?',
#    'responses': 'maybe we can go see a movie or something.'},
#   {'patterns': 'maybe we can go see a movie or something.',
#    'responses': "that sounds like fun. let's do it."},
#   {'patterns': "that sounds like fun. let's do it.",
#    'responses': "i'll see you tomorrow then."},
#   {'patterns': "i'll see you tomorrow then.",
#    'responses': 'see you then. goodbye.'},
#   {'patterns': 'hi, how are you. is alice there?',
#    'responses': "speaking. what's up?"},
#   {'patterns': "speaking. what's up?",
#    'responses': "why haven't you answered the phone?"},
#   {'patterns': "why haven't you answered the phone?",
#    'responses': 'my bad, i had chores to do.'},
#   {'patterns': 'my bad, i had chores to do.',
#    'responses': "that's all right."},
#   {'patterns': "that's all right.",
#    'responses': 'what was the reason for your call?'},
#   {'patterns': 'what was the reason for your call?',
#    'responses': 'i want to do something tomorrow with you.'},
#   {'patterns': 'i want to do something tomorrow with you.',
#    'responses': 'sounds good. what did you have in mind?'},
#   {'patterns': 'sounds good. what did you have in mind?',
#    'responses': 'i was thinking about seeing a movie.'},
#   {'patterns': 'i was thinking about seeing a movie.',
#    'responses': "okay, let's go see a movie."},
#   {'patterns': "okay, let's go see a movie.", 'responses': 'until then.'},
#   {'patterns': 'until then.', 'responses': 'talk to you later.'},
#   {'patterns': 'is alice available?', 'responses': "you're talking to her."},
#   {'patterns': "you're talking to her.",
#    'responses': "i've called you a hundred times today."},
#   {'patterns': "i've called you a hundred times today.",
#    'responses': 'i was busy doing something. i apologize.'},
#   {'patterns': 'i was busy doing something. i apologize.',
#    'responses': 'no problem.'},
#   {'patterns': 'no problem.', 'responses': 'did you need something?'},
#   {'patterns': 'did you need something?',
#    'responses': 'do you want to do something tomorrow?'},
#   {'patterns': 'do you want to do something tomorrow?',
#    'responses': 'is there somewhere special you wanted to go?'},
#   {'patterns': 'is there somewhere special you wanted to go?',
#    'responses': 'how about a movie?'},
#   {'patterns': 'how about a movie?', 'responses': 'a movie sounds good.'},
#   {'patterns': 'a movie sounds good.', 'responses': 'call me tomorrow then.'},
#   {'patterns': 'have you seen the new girl in school?',
#    'responses': "no, i haven't."},
#   {'patterns': "no, i haven't.", 'responses': "she's really pretty."},
#   {'patterns': "she's really pretty.", 'responses': 'describe her to me.'},
#   {'patterns': 'describe her to me.', 'responses': "she's not too tall."},
#   {'patterns': "she's not too tall.", 'responses': 'well, how tall is she?'},
#   {'patterns': 'well, how tall is she?',
#    'responses': "she's about five feet even."},
#   {'patterns': "she's about five feet even.",
#    'responses': 'what does she look like, though?'},
#   {'patterns': 'what does she look like, though?',
#    'responses': 'she has pretty light brown eyes.'},
#   {'patterns': 'she has pretty light brown eyes.',
#    'responses': "i may know which girl you're talking about."},
#   {'patterns': "i may know which girl you're talking about.",
#    'responses': 'so you have seen her around?'},
#   {'patterns': 'so you have seen her around?', 'responses': 'yes, i have.'},
#   {'patterns': "there's a new girl in school, have you seen her yet?",
#    'responses': "i haven't seen her yet."},
#   {'patterns': "i haven't seen her yet.",
#    'responses': 'i think that she is very pretty.'},
#   {'patterns': 'i think that she is very pretty.',
#    'responses': 'tell me how she looks.'},
#   {'patterns': 'tell me how she looks.', 'responses': "she's kind of short."},
#   {'patterns': "she's kind of short.", 'responses': 'what height is she?'},
#   {'patterns': 'what height is she?',
#    'responses': "she's probably about five feet."},
#   {'patterns': "she's probably about five feet.",
#    'responses': "that's nice, but tell me what she looks like."},
#   {'patterns': "that's nice, but tell me what she looks like.",
#    'responses': 'the first thing i noticed was her beautiful brown eyes.'},
#   {'patterns': 'the first thing i noticed was her beautiful brown eyes.',
#    'responses': "i think i might've bumped into her before."},
#   {'patterns': "i think i might've bumped into her before.",
#    'responses': "are you telling me that you've seen her before?"},
#   {'patterns': "are you telling me that you've seen her before?",
#    'responses': 'i believe so.'},
#   {'patterns': 'have you met the new girl?', 'responses': 'no. have you?'},
#   {'patterns': 'no. have you?',
#    'responses': "she's one of the prettiest girls at the school."},
#   {'patterns': "she's one of the prettiest girls at the school.",
#    'responses': 'what does she look like?'},
#   {'patterns': 'what does she look like?',
#    'responses': "well, she's quite short."},
#   {'patterns': "well, she's quite short.",
#    'responses': 'how tall would you say that she is?'},
#   {'patterns': 'how tall would you say that she is?',
#    'responses': "i would say she's only five feet."},
#   {'patterns': "i would say she's only five feet.",
#    'responses': 'what about her facial features?'},
#   {'patterns': 'what about her facial features?',
#    'responses': 'she has light brown eyes, absolutely beautiful.'},
#   {'patterns': 'she has light brown eyes, absolutely beautiful.',
#    'responses': "i think i know who you're talking about."},
#   {'patterns': "i think i know who you're talking about.",
#    'responses': 'have you seen her?'},
#   {'patterns': "why weren't you at school yesterday?",
#    'responses': "i wasn't really feeling well."},
#   {'patterns': "i wasn't really feeling well.",
#    'responses': 'what was wrong with you?'},
#   {'patterns': 'what was wrong with you?',
#    'responses': 'my stomach was upset.'},
#   {'patterns': 'my stomach was upset.',
#    'responses': 'do you feel better now?'},
#   {'patterns': 'do you feel better now?',
#    'responses': "i don't really feel too well yet."},
#   {'patterns': "i don't really feel too well yet.",
#    'responses': 'do you want anything to make you feel better?'},
#   {'patterns': 'do you want anything to make you feel better?',
#    'responses': 'no, thanks. i already took some medicine.'},
#   {'patterns': 'no, thanks. i already took some medicine.',
#    'responses': 'i hope you feel better.'},
#   {'patterns': 'i hope you feel better.', 'responses': 'thank you.'},
#   {'patterns': 'what reason do you have for missing school?',
#    'responses': 'i was sick.'},
#   {'patterns': 'i was sick.', 'responses': 'how were you sick?'},
#   {'patterns': 'how were you sick?', 'responses': 'i had a stomachache.'},
#   {'patterns': 'i had a stomachache.', 'responses': 'did it get any better?'},
#   {'patterns': 'did it get any better?',
#    'responses': "i'm still feeling under the weather."},
#   {'patterns': "i'm still feeling under the weather.",
#    'responses': 'would you like anything for your stomach?'},
#   {'patterns': 'would you like anything for your stomach?',
#    'responses': 'i took something earlier.'},
#   {'patterns': 'i took something earlier.', 'responses': 'get better.'},
#   {'patterns': 'get better.', 'responses': 'thanks a lot.'},
#   {'patterns': "why didn't you go to school yesterday?",
#    'responses': "i stayed home because i wasn't feeling well."},
#   {'patterns': "i stayed home because i wasn't feeling well.",
#    'responses': 'what was your problem?'},
#   {'patterns': 'what was your problem?',
#    'responses': 'my stomach was bothering me.'},
#   {'patterns': 'my stomach was bothering me.',
#    'responses': 'are you feeling any better?'},
#   {'patterns': 'are you feeling any better?',
#    'responses': "i'm still feeling a little sick."},
#   {'patterns': "i'm still feeling a little sick.",
#    'responses': "i'm going to the store, would you like any pepto bismol?"},
#   {'patterns': "i'm going to the store, would you like any pepto bismol?",
#    'responses': "that's okay."},
#   {'patterns': "that's okay.", 'responses': 'i hope you feel better.'},
#   {'patterns': 'did you hear the good news?', 'responses': "no, i haven't."},
#   {'patterns': "no, i haven't.", 'responses': 'i got a promotion at my job.'},
#   {'patterns': 'i got a promotion at my job.', 'responses': 'did you really?'},
#   {'patterns': 'did you really?', 'responses': 'seriously, i am so excited.'},
#   {'patterns': 'seriously, i am so excited.',
#    'responses': 'well, congratulations.'},
#   {'patterns': 'well, congratulations.', 'responses': 'thank you.'},
#   {'patterns': 'thank you.', 'responses': "i'm so happy for you."},
#   {'patterns': "i'm so happy for you.", 'responses': 'really?'},
#   {'patterns': 'really?', 'responses': 'yes. you really deserved this.'},
#   {'patterns': 'yes. you really deserved this.', 'responses': 'you think so?'},
#   {'patterns': 'you think so?', 'responses': 'yes. good for you.'},
#   {'patterns': 'have you heard my good news?',
#    'responses': "you haven't told me anything yet."},
#   {'patterns': "you haven't told me anything yet.",
#    'responses': 'i got a promotion at work earlier this week.'},
#   {'patterns': 'i got a promotion at work earlier this week.',
#    'responses': 'is that right?'},
#   {'patterns': 'is that right?',
#    'responses': "it's the truth. i am really happy."},
#   {'patterns': "it's the truth. i am really happy.",
#    'responses': 'congratulations on your promotion.'},
#   {'patterns': 'congratulations on your promotion.',
#    'responses': 'thank you very much.'},
#   {'patterns': 'thank you very much.',
#    'responses': 'i am really excited for you.'},
#   {'patterns': 'i am really excited for you.', 'responses': 'are you really?'},
#   {'patterns': 'are you really?',
#    'responses': "i'm serious. you deserved this promotion."},
#   {'patterns': "i'm serious. you deserved this promotion.",
#    'responses': 'is that what you really think?'},
#   {'patterns': 'is that what you really think?', 'responses': 'yes, i do.'},
#   {'patterns': "i haven't told you what happened yet, have i?",
#    'responses': "i haven't heard anything."},
#   {'patterns': "i haven't heard anything.",
#    'responses': 'my boss offered me a promotion, and i took it.'},
#   {'patterns': 'my boss offered me a promotion, and i took it.',
#    'responses': 'are you serious?'},
#   {'patterns': 'are you serious?', 'responses': 'yes, i am really excited.'},
#   {'patterns': 'yes, i am really excited.',
#    'responses': "that's great. congratulations."},
#   {'patterns': "that's great. congratulations.",
#    'responses': 'i appreciate that.'},
#   {'patterns': 'i appreciate that.',
#    'responses': 'you have no idea how happy i am for you.'},
#   {'patterns': 'you have no idea how happy i am for you.',
#    'responses': 'for real?'},
#   {'patterns': 'you look really nice today. ',
#    'responses': 'thank you. i just got this outfit the other day.'},
#   {'patterns': 'thank you. i just got this outfit the other day.',
#    'responses': 'really, where did you get it?'},
#   {'patterns': 'really, where did you get it?',
#    'responses': "i got it from macy's."},
#   {'patterns': "i got it from macy's.", 'responses': "it's really nice."},
#   {'patterns': "it's really nice.",
#    'responses': 'thanks again. you look nice today, too.'},
#   {'patterns': 'thanks again. you look nice today, too.',
#    'responses': 'thank you. i just got these shoes today.'},
#   {'patterns': 'thank you. i just got these shoes today.',
#    'responses': 'really? what kind of shoes are they?'},
#   {'patterns': 'really? what kind of shoes are they?',
#    'responses': 'these are called all star chuck taylors.'},
#   {'patterns': 'these are called all star chuck taylors.',
#    'responses': 'i really like those. how much did they cost?'},
#   {'patterns': 'i really like those. how much did they cost?',
#    'responses': 'they were about forty dollars.'},
#   {'patterns': 'they were about forty dollars.',
#    'responses': "i think i'm going to go buy myself a pair."},
#   {'patterns': "i absolutely love what you're wearing today.",
#    'responses': 'you do? i just bought this outfit a couple days ago.'},
#   {'patterns': 'you do? i just bought this outfit a couple days ago.',
#    'responses': 'seriously, it looks really nice on you. where did you buy it from?'},
#   {'patterns': 'seriously, it looks really nice on you. where did you buy it from?',
#    'responses': "i bought it from the macy's at the santa anita mall."},
#   {'patterns': "i bought it from the macy's at the santa anita mall.",
#    'responses': 'i really like that outfit.'},
#   {'patterns': 'i really like that outfit.',
#    'responses': 'thanks. i think you look nice today, too.'},
#   {'patterns': 'thanks. i think you look nice today, too.',
#    'responses': 'thank you. i just bought these new shoes earlier today.'},
#   {'patterns': 'thank you. i just bought these new shoes earlier today.',
#    'responses': 'those are nice. what are they?'},
#   {'patterns': 'those are nice. what are they?',
#    'responses': 'these are some chucks.'},
#   {'patterns': 'these are some chucks.',
#    'responses': 'those are great. how much were they?'},
#   {'patterns': 'those are great. how much were they?',
#    'responses': 'i got them for forty.'},
#   {'patterns': 'i got them for forty.',
#    'responses': 'i think i might go and find me my own pair of chucks.'},
#   {'patterns': 'i think that you look very cute today.',
#    'responses': 'is that right? this is a brand new outfit.'},
#   {'patterns': 'is that right? this is a brand new outfit.',
#    'responses': 'what store did you get it from?'},
#   {'patterns': 'what store did you get it from?',
#    'responses': "i went to macy's and picked it out."},
#   {'patterns': "i went to macy's and picked it out.",
#    'responses': 'i love your outfit right now.'},
#   {'patterns': 'i love your outfit right now.',
#    'responses': 'well, i think you look nice today too.'},
#   {'patterns': 'well, i think you look nice today too.',
#    'responses': 'thanks. i found these new shoes earlier at the store.'},
#   {'patterns': 'thanks. i found these new shoes earlier at the store.',
#    'responses': 'i think that those are some really nice shoes. what kind are they?'},
#   {'patterns': 'i think that those are some really nice shoes. what kind are they?',
#    'responses': 'these are chucks.'},
#   {'patterns': 'these are chucks.',
#    'responses': 'your shoes look really nice. how much did you get them for?'},
#   {'patterns': 'your shoes look really nice. how much did you get them for?',
#    'responses': 'they only cost me about forty dollars.'},
#   {'patterns': 'tell me, what do you enjoy doing in your spare time?',
#    'responses': 'i enjoy drawing and painting.'},
#   {'patterns': 'i enjoy drawing and painting.',
#    'responses': 'you know how to draw and paint?'},
#   {'patterns': 'you know how to draw and paint?', 'responses': 'yes, i do.'},
#   {'patterns': 'yes, i do.',
#    'responses': 'when did you learn how to do that?'},
#   {'patterns': 'when did you learn how to do that?',
#    'responses': 'i learned back in high school.'},
#   {'patterns': 'i learned back in high school.',
#    'responses': 'oh, so you took an art class?'},
#   {'patterns': 'oh, so you took an art class?',
#    'responses': 'yeah, i loved that class.'},
#   {'patterns': 'yeah, i loved that class.',
#    'responses': "i see that you're pretty talented."},
#   {'patterns': "i see that you're pretty talented.",
#    'responses': 'thank you very much.'},
#   {'patterns': 'thank you very much.',
#    'responses': 'i wish i had a talent like that.'},
#   {'patterns': 'i wish i had a talent like that.',
#    'responses': "i'm sure you have a talent. it's just hidden."},
#   {'patterns': 'what kinds of things do you like to do?',
#    'responses': "i've always liked to draw and paint."},
#   {'patterns': "i've always liked to draw and paint.",
#    'responses': "i didn't know you knew how to draw and paint."},
#   {'patterns': "i didn't know you knew how to draw and paint.",
#    'responses': 'i do it every once in a while.'},
#   {'patterns': 'i do it every once in a while.',
#    'responses': 'how long have you known how to do that?'},
#   {'patterns': 'how long have you known how to do that?',
#    'responses': 'i first learned how to do it in high school.'},
#   {'patterns': 'i first learned how to do it in high school.',
#    'responses': 'did you take some sort of art class or something?'},
#   {'patterns': 'did you take some sort of art class or something?',
#    'responses': 'that was my favorite class.'},
#   {'patterns': 'that was my favorite class.',
#    'responses': 'you have got to be talented.'},
#   {'patterns': 'you have got to be talented.', 'responses': 'thanks.'},
#   {'patterns': 'thanks.', 'responses': 'if only i was talented.'},
#   {'patterns': 'if only i was talented.',
#    'responses': "you have a talent. you just don't know what it is yet."},
#   {'patterns': 'are there any hobbies you do?',
#    'responses': 'when i have time, i sometimes draw and paint.'},
#   {'patterns': 'when i have time, i sometimes draw and paint.',
#    'responses': 'oh, you actually do that?'},
#   {'patterns': 'oh, you actually do that?',
#    'responses': 'every so often, i do.'},
#   {'patterns': 'every so often, i do.',
#    'responses': 'did you always know how to draw and paint?'},
#   {'patterns': 'did you always know how to draw and paint?',
#    'responses': 'i was taught in high school how to draw and paint.'},
#   {'patterns': 'i was taught in high school how to draw and paint.',
#    'responses': 'you had an art class?'},
#   {'patterns': 'you had an art class?',
#    'responses': 'exactly, it was my favorite class.'},
#   {'patterns': 'exactly, it was my favorite class.',
#    'responses': "well, it's good that you're so talented."},
#   {'patterns': "well, it's good that you're so talented.",
#    'responses': 'i appreciate that.'},
#   {'patterns': 'i appreciate that.',
#    'responses': 'talent is a great thing, i wish i had one.'},
#   {'patterns': "what's your favorite movie?",
#    'responses': 'my favorite movie is superbad.'},
#   {'patterns': 'my favorite movie is superbad.',
#    'responses': 'oh, why is that?'},
#   {'patterns': 'oh, why is that?',
#    'responses': "it's the funniest movie that i've ever seen."},
#   {'patterns': "it's the funniest movie that i've ever seen.",
#    'responses': "that's true. it is a very funny movie."},
#   {'patterns': "that's true. it is a very funny movie.",
#    'responses': "you've seen it before? "},
#   {'patterns': "you've seen it before? ",
#    'responses': 'yes, i saw that movie the first day it came out in theaters.'},
#   {'patterns': 'yes, i saw that movie the first day it came out in theaters.',
#    'responses': "didn't you laugh through the whole movie? i did."},
#   {'patterns': "didn't you laugh through the whole movie? i did.",
#    'responses': 'me too. that movie brought tears to my eyes.'},
#   {'patterns': 'me too. that movie brought tears to my eyes.',
#    'responses': 'mine too.'},
#   {'patterns': 'mine too.',
#    'responses': 'i have it on dvd at my house if you want to come over and watch it.'},
#   {'patterns': 'i have it on dvd at my house if you want to come over and watch it.',
#    'responses': "sure, let's go."},
#   {'patterns': 'which movie is your favorite to watch?',
#    'responses': 'i have to say, my favorite movie is superbad.'},
#   {'patterns': 'i have to say, my favorite movie is superbad.',
#    'responses': 'is that right? why?'},
#   {'patterns': 'is that right? why?',
#    'responses': "honestly, it is one of the funniest movies i've seen in a long time."},
#   {'patterns': "honestly, it is one of the funniest movies i've seen in a long time.",
#    'responses': "you're right. that movie is hilarious."},
#   {'patterns': "you're right. that movie is hilarious.",
#    'responses': "i didn't think you saw that movie."},
#   {'patterns': "i didn't think you saw that movie.",
#    'responses': 'i went to see it the day it came out.'},
#   {'patterns': 'i went to see it the day it came out.',
#    'responses': 'i was laughing through the whole movie.'},
#   {'patterns': 'i was laughing through the whole movie.',
#    'responses': "i couldn't help laughing, either. "},
#   {'patterns': "i couldn't help laughing, either. ",
#    'responses': 'same here.'},
#   {'patterns': 'same here.',
#    'responses': 'i bought the movie. would you like to come to my house and watch it?'},
#   {'patterns': 'i bought the movie. would you like to come to my house and watch it?',
#    'responses': 'of course.'},
#   {'patterns': "out of every movie that you've seen, which one is your favorite?",
#    'responses': "i'm going to have to say that superbad is the best movie ever."},
#   {'patterns': "i'm going to have to say that superbad is the best movie ever.",
#    'responses': 'you think so, how come?'},
#   {'patterns': 'you think so, how come?',
#    'responses': 'well, superbad is super funny.'},
#   {'patterns': 'well, superbad is super funny.',
#    'responses': "you're not lying, i found that movie absolutely hilarious."},
#   {'patterns': "you're not lying, i found that movie absolutely hilarious.",
#    'responses': "i didn't know that you saw superbad before."},
#   {'patterns': "i didn't know that you saw superbad before.",
#    'responses': 'i made sure to be in line to see it the first day it came out.'},
#   {'patterns': 'i made sure to be in line to see it the first day it came out.',
#    'responses': "i couldn't keep from laughing throughout the whole movie."},
#   {'patterns': "i couldn't keep from laughing throughout the whole movie.",
#    'responses': 'i was laughing hysterically the whole time; my stomach muscles hurt afterwards.'},
#   {'patterns': 'i was laughing hysterically the whole time; my stomach muscles hurt afterwards.',
#    'responses': "that's exactly how i felt."},
#   {'patterns': "that's exactly how i felt.",
#    'responses': 'i got the movie when it came out on dvd, do you want to come over?'},
#   {'patterns': 'what type of music do you like to listen to?',
#    'responses': 'i like listening to different kinds of music.'},
#   {'patterns': 'i like listening to different kinds of music.',
#    'responses': 'like what, for instance?'},
#   {'patterns': 'like what, for instance?',
#    'responses': 'i enjoy rock and r&b.'},
#   {'patterns': 'i enjoy rock and r&b.', 'responses': 'why is that?'},
#   {'patterns': 'why is that?',
#    'responses': 'i like the different instruments that they use.'},
#   {'patterns': 'i like the different instruments that they use.',
#    'responses': "that's a good reason to like something."},
#   {'patterns': "that's a good reason to like something.",
#    'responses': 'yeah, i think so too.'},
#   {'patterns': 'what kind of music do you enjoy listening to?',
#    'responses': 'i enjoy listening to all kinds of music.'},
#   {'patterns': 'i enjoy listening to all kinds of music.',
#    'responses': 'what kind?'},
#   {'patterns': 'what kind?', 'responses': 'i like to listen to rock and r&b.'},
#   {'patterns': 'i like to listen to rock and r&b.',
#    'responses': 'why do you like that type of music?'},
#   {'patterns': 'why do you like that type of music?',
#    'responses': 'i like the kinds of instruments that they use.'},
#   {'patterns': 'i like the kinds of instruments that they use.',
#    'responses': "i think that's an excellent reason to like something."},
#   {'patterns': "i think that's an excellent reason to like something.",
#    'responses': 'thanks, i feel the same way.'},
#   {'patterns': 'what is your favorite kind of music?',
#    'responses': 'i listen to various types of music.'},
#   {'patterns': 'i listen to various types of music.',
#    'responses': 'what genres?'},
#   {'patterns': 'what genres?',
#    'responses': 'i enjoy listening to both rock and r&b.'},
#   {'patterns': 'i enjoy listening to both rock and r&b.',
#    'responses': 'what interests you in that type of music?'},
#   {'patterns': 'what interests you in that type of music?',
#    'responses': 'i enjoy the different types of instruments that they use.'},
#   {'patterns': 'i enjoy the different types of instruments that they use.',
#    'responses': 'that is a perfect reason to like a certain kind of music.'},
#   {'patterns': 'did you go to the basketball game on friday?',
#    'responses': "no, i couldn't make it."},
#   {'patterns': "no, i couldn't make it.",
#    'responses': 'you missed a really good game.'},
#   {'patterns': 'you missed a really good game.',
#    'responses': 'oh, really? who won?'},
#   {'patterns': 'oh, really? who won?',
#    'responses': 'our school did. they played really well.'},
#   {'patterns': 'our school did. they played really well.',
#    'responses': 'too bad i was busy. i really wanted to go.'},
#   {'patterns': 'too bad i was busy. i really wanted to go.',
#    'responses': 'yeah, you should have. it was really exciting.'},
#   {'patterns': 'yeah, you should have. it was really exciting.',
#    'responses': 'so what was the score?'},
#   {'patterns': 'so what was the score?', 'responses': 'the score was 101-98.'},
#   {'patterns': 'the score was 101-98.',
#    'responses': 'man, that was a really close game.'},
#   {'patterns': 'man, that was a really close game.',
#    'responses': "that's what made it so great."},
#   {'patterns': "that's what made it so great.",
#    'responses': "i'll make sure and make it to the next one."},
#   {'patterns': "were you able to attend friday night's basketball game?",
#    'responses': 'i was unable to make it.'},
#   {'patterns': 'i was unable to make it.',
#    'responses': 'you should have been there. it was intense.'},
#   {'patterns': 'you should have been there. it was intense.',
#    'responses': 'is that right. who ended up winning?'},
#   {'patterns': 'is that right. who ended up winning?',
#    'responses': 'our team was victorious.'},
#   {'patterns': 'our team was victorious.',
#    'responses': "i wish i was free that night. i'm kind of mad that i didn't go."},
#   {'patterns': "i wish i was free that night. i'm kind of mad that i didn't go.",
#    'responses': 'it was a great game.'},
#   {'patterns': 'it was a great game.',
#    'responses': 'what was the score at the end of the game?'},
#   {'patterns': 'what was the score at the end of the game?',
#    'responses': 'our team won 101-98.'},
#   {'patterns': 'our team won 101-98.',
#    'responses': 'sounds like it was a close game.'},
#   {'patterns': 'sounds like it was a close game.',
#    'responses': "that's the reason it was such a great game."},
#   {'patterns': "that's the reason it was such a great game.",
#    'responses': 'the next game, i will definitely be there.'},
#   {'patterns': 'i was meaning to ask you if you saw the basketball game on friday.',
#    'responses': "i wanted to go, but i couldn't."},
#   {'patterns': "i wanted to go, but i couldn't.",
#    'responses': 'it was a great game.'},
#   {'patterns': 'it was a great game.',
#    'responses': "it's too bad that i couldn't make it. who won?"},
#   {'patterns': "it's too bad that i couldn't make it. who won?",
#    'responses': 'our team played hard and won.'},
#   {'patterns': 'our team played hard and won.',
#    'responses': 'i really wish i went to the game.'},
#   {'patterns': 'i really wish i went to the game.',
#    'responses': 'it was the best game ever.'},
#   {'patterns': 'it was the best game ever.',
#    'responses': 'so tell me the final score.'},
#   {'patterns': 'so tell me the final score.',
#    'responses': 'the other team lost by three points, 101-98. '},
#   {'patterns': 'the other team lost by three points, 101-98. ',
#    'responses': "it must've been a close game."},
#   {'patterns': "it must've been a close game.",
#    'responses': "it really was. you should've gone."},
#   {'patterns': 'what are you doing this weekend?',
#    'responses': "i'm going to the movies with a friend. how about you?"},
#   {'patterns': "i'm going to the movies with a friend. how about you?",
#    'responses': "i'm not sure yet."},
#   {'patterns': "i'm not sure yet.",
#    'responses': 'well, did you want to go see a movie with me?'},
#   {'patterns': 'well, did you want to go see a movie with me?',
#    'responses': 'what movie are you going to see?'},
#   {'patterns': 'what movie are you going to see?',
#    'responses': "i'm not sure yet. is there something you want to see?"},
#   {'patterns': "i'm not sure yet. is there something you want to see?",
#    'responses': "there's nothing i can think of."},
#   {'patterns': "there's nothing i can think of.",
#    'responses': 'so, did you want to go?'},
#   {'patterns': 'so, did you want to go?',
#    'responses': 'no, thanks, maybe another time.'},
#   {'patterns': 'no, thanks, maybe another time.',
#    'responses': 'okay, sounds good.'},
#   {'patterns': "do you know what you're going to do this weekend?",
#    'responses': 'i am going to see a movie with a friend of mine. what about you?'},
#   {'patterns': 'i am going to see a movie with a friend of mine. what about you?',
#    'responses': "i don't know."},
#   {'patterns': "i don't know.",
#    'responses': 'would you like to see a movie with me and my friend?'},
#   {'patterns': 'would you like to see a movie with me and my friend?',
#    'responses': "do you know what movie you're going to watch?"},
#   {'patterns': "do you know what movie you're going to watch?",
#    'responses': "i don't know, but was there a certain movie you wanted to see?"},
#   {'patterns': "i don't know, but was there a certain movie you wanted to see?",
#    'responses': 'none that i can think of.'},
#   {'patterns': 'none that i can think of.',
#    'responses': 'well, would you like to go?'},
#   {'patterns': 'well, would you like to go?',
#    'responses': "thank you for inviting me, but i think i'll pass."},
#   {'patterns': "thank you for inviting me, but i think i'll pass.",
#    'responses': 'all right. another time then.'},
#   {'patterns': 'you have any ideas as to what you want to do this weekend?',
#    'responses': "i'm going to the movie theater with my friend. what are you going to do?"},
#   {'patterns': "i'm going to the movie theater with my friend. what are you going to do?",
#    'responses': "i'm not quite sure yet."},
#   {'patterns': "i'm not quite sure yet.",
#    'responses': 'how about you see a movie with me and my friend?'},
#   {'patterns': 'how about you see a movie with me and my friend?',
#    'responses': 'what movie are you and your friend planning on watching?'},
#   {'patterns': 'what movie are you and your friend planning on watching?',
#    'responses': 'not sure. is there a movie out that catches your eye?'},
#   {'patterns': 'not sure. is there a movie out that catches your eye?',
#    'responses': 'no good movies come to mind.'},
#   {'patterns': 'no good movies come to mind.',
#    'responses': 'have you decided whether or not you would like to go?'},
#   {'patterns': 'have you decided whether or not you would like to go?',
#    'responses': 'no, thanks. maybe another time.'},
#   {'patterns': 'did you go to school today?',
#    'responses': 'yeah, i went to school today. were you there?'},
#   {'patterns': 'yeah, i went to school today. were you there?',
#    'responses': "no, i didn't go, i've been sick."},
#   {'patterns': "no, i didn't go, i've been sick.",
#    'responses': 'that sucks. did you want the assignments from english class?'},
#   {'patterns': 'that sucks. did you want the assignments from english class?',
#    'responses': 'that would be nice, thank you.'},
#   {'patterns': 'that would be nice, thank you.',
#    'responses': "no problem, you're welcome."},
#   {'patterns': "no problem, you're welcome.",
#    'responses': "i will be glad to do the same for you when you're sick."},
#   {'patterns': "i will be glad to do the same for you when you're sick.",
#    'responses': 'well, thank you. i hope to see you at school tomorrow.'},
#   {'patterns': 'have you attended school today?',
#    'responses': 'i attended school today. did you?'},
#   {'patterns': 'i attended school today. did you?',
#    'responses': "i wasn't able to attend school because i was feeling ill."},
#   {'patterns': "i wasn't able to attend school because i was feeling ill.",
#    'responses': "i'm sorry to hear that. would you like the assignments from english class?"},
#   {'patterns': "i'm sorry to hear that. would you like the assignments from english class?",
#    'responses': 'i would really appreciate that, thanks.'},
#   {'patterns': 'i would really appreciate that, thanks.',
#    'responses': "it's no trouble at all."},
#   {'patterns': "it's no trouble at all.",
#    'responses': "if you get sick, i'll return the favor."},
#   {'patterns': "if you get sick, i'll return the favor.",
#    'responses': 'thanks. see you at school tomorrow if you feel better.'},
# ...
#   {'patterns': 'they are bites.', 'responses': 'did the cat bite you?'},
#   {'patterns': 'did the cat bite you?',
#    'responses': 'no. the bedbugs in that mattress bit me.'},
#   {'patterns': 'no. the bedbugs in that mattress bit me.',
#    'responses': "okay. let's get a new mattress."},
#   {'patterns': 'my laptop is so slow.', 'responses': 'buy a new one.'},
#   {'patterns': 'buy a new one.', 'responses': 'i would if i had the money.'},
#   {'patterns': 'i would if i had the money.',
#    'responses': 'why is it so slow?'},
#   {'patterns': 'why is it so slow?', 'responses': "that's a good question."},
#   {'patterns': "that's a good question.",
#    'responses': 'did you take it to a computer shop?'},
#   {'patterns': 'did you take it to a computer shop?',
#    'responses': 'i would if i had the money.'},
#   {'patterns': 'i would if i had the money.',
#    'responses': 'well, i guess you have to live with it.'},
#   {'patterns': 'well, i guess you have to live with it.',
#    'responses': 'sometimes i want to throw it out the window.'},
#   {'patterns': 'sometimes i want to throw it out the window.',
#    'responses': "you don't want to do that."},
#   {'patterns': "you don't want to do that.", 'responses': 'why not?'},
#   {'patterns': 'why not?', 'responses': 'you might hit someone in the head.'},
#   {'patterns': "what's for dinner?", 'responses': "i'm not sure."},
#   {'patterns': "i'm not sure.", 'responses': 'how about a pizza?'},
#   {'patterns': 'how about a pizza?', 'responses': 'you had pizza for lunch.'},
#   {'patterns': 'you had pizza for lunch.', 'responses': 'but i love pizza.'},
#   {'patterns': 'but i love pizza.', 'responses': 'everybody loves pizza.'},
#   {'patterns': 'everybody loves pizza.',
#    'responses': "so why can't i have pizza for dinner?"},
#   {'patterns': "so why can't i have pizza for dinner?",
#    'responses': 'because you need variety.'},
#   {'patterns': 'because you need variety.', 'responses': 'what\'s "variety?'},
#   {'patterns': 'what\'s "variety?',
#    'responses': 'different things\x97not the same thing all the time.'},
#   {'patterns': 'different things\x97not the same thing all the time.',
#    'responses': 'you mean, like a pepperoni pizza instead of a cheese pizza?'},
#   {'patterns': 'you mean, like a pepperoni pizza instead of a cheese pizza?',
#    'responses': 'no, i mean a salad instead of a pizza.'},
#   {'patterns': 'we need to save money.',
#    'responses': 'why do we need to save money?'},
#   {'patterns': 'why do we need to save money?',
#    'responses': 'because we need to buy a house.'},
#   {'patterns': 'because we need to buy a house.',
#    'responses': 'but a house is so expensive.'},
#   {'patterns': 'but a house is so expensive.',
#    'responses': "that's why we need to save money."},
#   {'patterns': "that's why we need to save money.",
#    'responses': 'how much do we need to save?'},
#   {'patterns': 'how much do we need to save?',
#    'responses': 'we need to save enough for a down payment.'},
#   {'patterns': 'we need to save enough for a down payment.',
#    'responses': 'how much is that?'},
#   {'patterns': 'how much is that?', 'responses': "that's about $30,000."},
#   {'patterns': "that's about $30,000.",
#    'responses': 'thirty thousand dollars! that will take forever.'},
#   {'patterns': 'thirty thousand dollars! that will take forever.',
#    'responses': 'not if we save every penny.'},
#   {'patterns': 'not if we save every penny.',
#    'responses': "okay. here's seven pennies."},
#   {'patterns': 'the ocean is so big.',
#    'responses': "you can't see the end of it."},
#   {'patterns': "you can't see the end of it.",
#    'responses': 'it goes on and on forever.'},
#   {'patterns': 'it goes on and on forever.',
#    'responses': "and it's deep, too."},
#   {'patterns': "and it's deep, too.",
#    'responses': "i think it's five miles deep."},
#   {'patterns': "i think it's five miles deep.",
#    'responses': 'are there fish at the bottom?'},
#   {'patterns': 'are there fish at the bottom?',
#    'responses': 'there are fish at the top and the bottom.'},
#   {'patterns': 'there are fish at the top and the bottom.',
#    'responses': 'are there more fish or more people?'},
#   {'patterns': 'are there more fish or more people?',
#    'responses': 'i think there are more fish.'},
#   {'patterns': 'i think there are more fish.',
#    'responses': 'i hope so. i love to eat fish.'},
#   {'patterns': "i'm upset with my mom.", 'responses': 'why is that?'},
#   {'patterns': 'why is that?',
#    'responses': "i warned her about her new boyfriend. she didn't listen to me."},
#   {'patterns': "i warned her about her new boyfriend. she didn't listen to me.",
#    'responses': 'what happened?'},
#   {'patterns': 'what happened?',
#    'responses': 'i gave her $1,000 for her birthday. i told her to spend it on herself.'},
#   {'patterns': 'i gave her $1,000 for her birthday. i told her to spend it on herself.',
#    'responses': 'that was very nice of you.'},
#   {'patterns': 'that was very nice of you.',
#    'responses': 'i found out that she gave it to her new boyfriend.'},
#   {'patterns': 'i found out that she gave it to her new boyfriend.',
#    'responses': 'why did she do that?'},
#   {'patterns': 'why did she do that?',
#    'responses': 'he said he would buy her a nice ring.'},
#   {'patterns': 'he said he would buy her a nice ring.',
#    'responses': "what's wrong with that?"},
#   {'patterns': "what's wrong with that?",
#    'responses': 'he went to las vegas. he lost it all gambling.'},
#   {'patterns': 'he went to las vegas. he lost it all gambling.',
#    'responses': 'i hope your mom broke up with him.'},
#   {'patterns': 'do animals talk to each other?',
#    'responses': 'of course they talk to each other.'},
#   {'patterns': 'of course they talk to each other.',
#    'responses': 'what do they talk about?'},
#   {'patterns': 'what do they talk about?',
#    'responses': 'they talk about other animals.'},
#   {'patterns': 'they talk about other animals.',
#    'responses': 'what else do they talk about?'},
#   {'patterns': 'what else do they talk about?',
#    'responses': 'they talk about food and the weather.'},
#   {'patterns': 'they talk about food and the weather.',
#    'responses': 'do they talk about us?'},
#   {'patterns': 'do they talk about us?',
#    'responses': 'of course they talk about us.'},
#   {'patterns': 'of course they talk about us.',
#    'responses': 'what do they say about us?'},
#   {'patterns': 'what do they say about us?',
#    'responses': 'they say that we are funny-looking.'},
#   {'patterns': 'they say that we are funny-looking.',
#    'responses': "ha! we're not funny-looking; animals are funny-looking."},
#   {'patterns': "ha! we're not funny-looking; animals are funny-looking.",
#    'responses': "we're funny-looking because we wear clothes."},
#   {'patterns': 'i have to clean the house.',
#    'responses': "yes, it's very dirty."},
#   {'patterns': "yes, it's very dirty.", 'responses': 'you can help me.'},
#   {'patterns': 'you can help me.', 'responses': 'why me?'},
#   {'patterns': 'why me?', 'responses': 'because you helped make it dirty.'},
#   {'patterns': 'because you helped make it dirty.',
#    'responses': 'what do you want me to do?'},
#   {'patterns': 'what do you want me to do?',
#    'responses': 'i want you to clean the bathroom.'},
#   {'patterns': 'i want you to clean the bathroom.',
#    'responses': "oh, that's easy."},
#   {'patterns': "oh, that's easy.",
#    'responses': 'clean the sink, the tub, the counter, and the toilet.'},
#   {'patterns': 'clean the sink, the tub, the counter, and the toilet.',
#    'responses': "that's a lot of work."},
#   {'patterns': "that's a lot of work.",
#    'responses': 'tell me when you finish.'},
#   {'patterns': 'tell me when you finish.',
#    'responses': "i don't think so. you'll just give me more work."},
#   {'patterns': "you're watching too much tv.",
#    'responses': 'what do you mean?'},
#   {'patterns': 'what do you mean?',
#    'responses': "i mean you're wasting your life."},
#   {'patterns': "i mean you're wasting your life.",
#    'responses': "i'm having fun."},
#   {'patterns': "i'm having fun.",
#    'responses': "you're sitting there with your mouth open."},
#   {'patterns': "you're sitting there with your mouth open.",
#    'responses': 'who cares?'},
#   {'patterns': 'who cares?', 'responses': 'i care. do something.'},
#   {'patterns': 'i care. do something.', 'responses': 'okay. i did something.'},
#   {'patterns': 'okay. i did something.', 'responses': 'what did you do?'},
#   {'patterns': 'what did you do?', 'responses': 'i turned up the volume.'},
#   {'patterns': 'i turned up the volume.',
#    'responses': 'that\'s not what i meant by "do something."'},
#   {'patterns': 'that\'s not what i meant by "do something."',
#    'responses': 'will you do something? leave me alone.'},
#   {'patterns': 'did you write a letter to grandma?',
#    'responses': 'yes, i did.'},
#   {'patterns': 'yes, i did.', 'responses': 'did you tell her about school?'},
#   {'patterns': 'did you tell her about school?',
#    'responses': 'i told her that school is fun.'},
#   {'patterns': 'i told her that school is fun.',
#    'responses': 'did you put the letter in an envelope?'},
#   {'patterns': 'did you put the letter in an envelope?',
#    'responses': 'yes, and i sealed the envelope.'},
#   {'patterns': 'yes, and i sealed the envelope.',
#    'responses': 'did you put a stamp on the envelope?'},
#   {'patterns': 'did you put a stamp on the envelope?',
#    'responses': "i couldn't find any stamps."},
#   {'patterns': "i couldn't find any stamps.",
#    'responses': "they're in the kitchen drawer."},
#   {'patterns': "they're in the kitchen drawer.",
#    'responses': 'okay. i just put a stamp on the envelope.'},
#   {'patterns': 'okay. i just put a stamp on the envelope.',
#    'responses': "give me the envelope, and i'll mail it for you."},
#   {'patterns': "give me the envelope, and i'll mail it for you.",
#    'responses': 'when is grandma going to learn about e-mail?'},
#   {'patterns': 'why are you yawning?', 'responses': "i'm sleepy."},
#   {'patterns': "i'm sleepy.", 'responses': "why don't you go to bed?"},
#   {'patterns': "why don't you go to bed?",
#    'responses': 'i want to watch this tv show.'},
#   {'patterns': 'i want to watch this tv show.',
#    'responses': 'maybe you should record it.'},
#   {'patterns': 'maybe you should record it.',
#    'responses': 'the tape recorder is broken.'},
#   {'patterns': 'the tape recorder is broken.',
#    'responses': 'then you should watch the rerun.'},
#   {'patterns': 'then you should watch the rerun.',
#    'responses': "why? i'm watching the original."},
#   {'patterns': "why? i'm watching the original.",
#    'responses': "but you'll be asleep in about one minute."},
#   {'patterns': "but you'll be asleep in about one minute.",
#    'responses': "i'm just yawning because the commercials are on."},
#   {'patterns': "i'm just yawning because the commercials are on.",
#    'responses': "okay. i'll tell you how the show ends."},
#   {'patterns': "okay. i'll tell you how the show ends.", 'responses': 'zzz.'},
#   {'patterns': "it's sunday.", 'responses': 'so?'},
#   {'patterns': 'so?', 'responses': 'you know what that means.'},
#   {'patterns': 'you know what that means.', 'responses': 'i forgot.'},
#   {'patterns': 'i forgot.', 'responses': 'sunday means we go to church.'},
#   {'patterns': 'sunday means we go to church.', 'responses': 'oh, yeah.'},
#   {'patterns': 'oh, yeah.', 'responses': 'put on a coat and tie.'},
#   {'patterns': 'put on a coat and tie.', 'responses': 'why?'},
#   {'patterns': 'why?', 'responses': 'to show respect to god and others.'},
#   {'patterns': 'to show respect to god and others.',
#    'responses': "i'm glad sunday is only once a week."},
#   {'patterns': "i'm glad sunday is only once a week.",
#    'responses': "i hope god didn't hear that."},
#   {'patterns': "i hope god didn't hear that.",
#    'responses': "he'll forgive me."},
#   {'patterns': 'did you feed the cat?',
#    'responses': "i'll do that in a minute."},
#   {'patterns': "i'll do that in a minute.",
#    'responses': "the cat is meowing. he's hungry."},
#   {'patterns': "the cat is meowing. he's hungry.",
#    'responses': "okay. i'll feed him right now."},
#   {'patterns': "okay. i'll feed him right now.",
#    'responses': "you shouldn't make him wait."},
#   {'patterns': "you shouldn't make him wait.",
#    'responses': 'i was doing my homework.'},
#   {'patterns': 'i was doing my homework.',
#    'responses': "the cat doesn't care about your homework."},
#   {'patterns': "the cat doesn't care about your homework.",
#    'responses': "the cat doesn't care about anything."},
#   {'patterns': "the cat doesn't care about anything.",
#    'responses': "that's the way cats are."},
#   {'patterns': "that's the way cats are.",
#    'responses': 'all they think about is themselves.'},
#   {'patterns': 'all they think about is themselves.',
#    'responses': 'maybe we should get rid of him.'},
#   {'patterns': 'maybe we should get rid of him.',
#    'responses': "of course not! he's family."},
#   {'patterns': 'i hate shaving.', 'responses': 'me too.'},
#   {'patterns': 'me too.', 'responses': 'i just cut myself again.'},
#   {'patterns': 'i just cut myself again.',
#    'responses': 'did you use a new blade?'},
#   {'patterns': 'did you use a new blade?',
#    'responses': "it doesn't matter. old blades cut, new blades cut."},
#   {'patterns': "it doesn't matter. old blades cut, new blades cut.",
#    'responses': 'maybe you should use an electric shaver.'},
#   {'patterns': 'maybe you should use an electric shaver.',
#    'responses': "they make a lot of noise, but they don't give a close shave."},
#   {'patterns': "they make a lot of noise, but they don't give a close shave.",
#    'responses': 'maybe you should stop shaving.'},
#   {'patterns': 'maybe you should stop shaving.',
#    'responses': 'and grow a beard?'},
#   {'patterns': 'and grow a beard?', 'responses': 'sure. why not?'},
#   {'patterns': 'sure. why not?',
#    'responses': 'because food and other stuff sticks in my beard.'},
#   {'patterns': 'because food and other stuff sticks in my beard.',
#    'responses': "hmm. here's an idea. put cream on your face and have the cat lick it off."},
#   {'patterns': 'excuse me.', 'responses': 'yes?'},
#   {'patterns': 'yes?', 'responses': 'are you reading this paper?'},
#   {'patterns': 'are you reading this paper?',
#    'responses': 'oh, no. help yourself.'},
#   {'patterns': 'oh, no. help yourself.',
#    'responses': 'i asked because the paper is sitting next to you.'},
#   {'patterns': 'i asked because the paper is sitting next to you.',
#    'responses': "thank you. that's polite of you to ask."},
#   {'patterns': "thank you. that's polite of you to ask.",
#    'responses': 'some people would just pick it up.'},
#   {'patterns': 'some people would just pick it up.',
#    'responses': 'yes, i know. some people are rude.'},
#   {'patterns': 'yes, i know. some people are rude.',
#    'responses': 'i always try to be polite.'},
#   {'patterns': 'i always try to be polite.', 'responses': 'so do i.'},
#   {'patterns': 'so do i.',
#    'responses': 'the world needs more polite people like us.'},
#   {'patterns': 'the world needs more polite people like us.',
#    'responses': 'i agree 100 percent.'},
#   {'patterns': 'mom, i want a puppy.', 'responses': 'let me think about it.'},
#   {'patterns': 'let me think about it.',
#    'responses': 'why do you have to think about it?'},
#   {'patterns': 'why do you have to think about it?',
#    'responses': 'because a puppy costs money.'},
#   {'patterns': 'because a puppy costs money.',
#    'responses': "no, it doesn't. puppies are free."},
#   {'patterns': "no, it doesn't. puppies are free.",
#    'responses': 'yes, but a puppy needs shots.'},
#   {'patterns': 'yes, but a puppy needs shots.',
#    'responses': 'shots for what?'},
#   {'patterns': 'shots for what?',
#    'responses': "so it won't get sick. just like you get shots."},
#   {'patterns': "so it won't get sick. just like you get shots.",
#    'responses': 'i hate shots.'},
#   {'patterns': 'i hate shots.',
#    'responses': 'and a puppy eats food. food costs money.'},
#   {'patterns': 'and a puppy eats food. food costs money.',
#    'responses': "no problem. i'll give him food off my plate."},
#   ...]}
